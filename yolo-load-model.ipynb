# %% [markdown]
# # Detecting garbage by trained model

# %% [markdown]
# #### Import trained model

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("Yolov11m_trained_80_epoch.pt")

# Display model information (optional)
model.info()
# Out:
# YOLO11m summary (fused): 303 layers, 20,034,658 parameters, 0 gradients, 67.7 GFLOPs
# (303, 20034658, 0, 67.67150079999999)

# %% [markdown]
# #### Function to save detected object by model to a NoSQL Database

# %% [markdown]
# #### connecting to mongodb database

# %% [markdown]
# Before starting the next cell, you must run the command ```mongod ``` in command prompt, then run ```mongosh``` in another command prompt so mongodb can work

# %%
# Run mongod and mongosh
from pymongo import MongoClient
import datetime
import numpy as np
from bson.binary import Binary

# Run Client
client = MongoClient("localhost", 27017)
db = client['IRS']
collection = db["detections"]  # Collection name

# %% [markdown]
# Detecting using cam

# %%
import cv2
import time
# Initialize the webcam

# Initialize variables for tracking object detection time
detection_times = []
num_frames_to_track = 5  # Number of frames to track for average time

cap = cv2.VideoCapture(0)  # 0 for default webcam

while cap.isOpened():
    
    start_time = time.time()  # Record start time for frame processing
    
    # Read a frame from the webcam
    success, frame = cap.read()

    if success:
        # Run inference on the frame
        results = model(frame, conf = 0.80)

        # Get the annotated frame with bounding boxes
        annotated_frame = results[0].plot()

        # Record end time for frame processing
        end_time = time.time()  
        
        # Calculate frame processing time
        processing_time = end_time - start_time  

        # Add detection time to list
        detection_times.append(processing_time)  

        # Keep only the last 'num_frames_to_track' times for averaging
        if len(detection_times) > num_frames_to_track:
            detection_times = detection_times[-num_frames_to_track:]
        
        cls = None
        # Show item type scanned
        for r in results:
            for c in r.boxes.cls:
                cls = model.names[int(c)]
        
        
        # Font Settings 
        text_y_position = 30
        font_scale = 0.5  # Reduced font scale for smaller text
        font_thickness = 1  # Reduced thickness (optional)

        # Convert frame to binary for MongoDB storage
        _, buffer = cv2.imencode(".jpg", annotated_frame)
        image_binary = Binary(buffer.tobytes())  # BSON Binary format
        
        # Calculate and display average detection time
        average_detection_time = sum(detection_times) / len(detection_times)
        cv2.putText(annotated_frame, f"Item detected: {cls}", (10, text_y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, font_scale, (0, 255, 0), font_thickness)
        text_y_position += 20  # Adjust vertical spacing as needed

        # Make a var to check weather the item scanned or not to avoid redundant items
        is_detected = False
        # Save img of item scanned
        if cls != None:
            if not is_detected:
                # Store image & metadata in one document
                detection_data = {
                    "image": image_binary,
                    "detected_item": cls,
                    "timestamp": datetime.datetime.now(),
                    "processing_time": processing_time
                }
                collection.insert_one(detection_data)        
            is_detected = True
        

        # Display the annotated frame
        cv2.imshow("YOLOv11 Object Detection", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        print("Error reading frame from webcam.")
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows
9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 GLASS, 912.4ms
# Speed: 6.4ms preprocess, 912.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 893.0ms
# Speed: 7.6ms preprocess, 893.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 929.7ms
# Speed: 3.6ms preprocess, 929.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1174.2ms
# Speed: 6.1ms preprocess, 1174.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1352.1ms
# Speed: 12.2ms preprocess, 1352.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1217.8ms
# Speed: 14.1ms preprocess, 1217.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1239.2ms
# Speed: 4.8ms preprocess, 1239.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1253.9ms
# Speed: 7.2ms preprocess, 1253.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1236.7ms
# Speed: 8.9ms preprocess, 1236.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1206.8ms
# Speed: 4.4ms preprocess, 1206.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 983.7ms
# Speed: 5.5ms preprocess, 983.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 967.1ms
# Speed: 3.6ms preprocess, 967.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PAPER, 965.9ms
# Speed: 4.0ms preprocess, 965.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 944.9ms
# Speed: 11.4ms preprocess, 944.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 950.3ms
# Speed: 8.2ms preprocess, 950.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 922.9ms
# Speed: 3.5ms preprocess, 922.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 958.3ms
# Speed: 7.8ms preprocess, 958.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1121.2ms
# Speed: 3.4ms preprocess, 1121.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1227.2ms
# Speed: 16.3ms preprocess, 1227.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1270.8ms
# Speed: 4.5ms preprocess, 1270.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1253.7ms
# Speed: 5.3ms preprocess, 1253.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1219.9ms
# Speed: 15.5ms preprocess, 1219.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1478.2ms
# Speed: 4.9ms preprocess, 1478.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1242.0ms
# Speed: 7.3ms preprocess, 1242.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 956.1ms
# Speed: 3.6ms preprocess, 956.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PAPER, 971.4ms
# Speed: 9.0ms preprocess, 971.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 942.2ms
# Speed: 3.7ms preprocess, 942.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PAPER, 923.8ms
# Speed: 3.4ms preprocess, 923.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 948.1ms
# Speed: 7.2ms preprocess, 948.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 PAPER, 933.8ms
# Speed: 6.1ms preprocess, 933.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 990.7ms
# Speed: 5.5ms preprocess, 990.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1100.7ms
# Speed: 5.3ms preprocess, 1100.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1338.3ms
# Speed: 4.8ms preprocess, 1338.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 1225.3ms
# Speed: 6.2ms preprocess, 1225.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# #### Show items stored in the database

# %%
# Run mongod and mongosh
from pymongo import MongoClient
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import io

client = MongoClient("localhost", 27017)
db = client['IRS']
collection = db["detections"]  # Collection name

# Show all images of items stored in database
n = collection.count_documents({})
w = 5
h = 4
fig = plt.figure(figsize=(16, 9))
columns = 4
rows = (n // columns) + (n % columns > 0)

imgs = list(collection.find({}))

for i, img_doc in enumerate(imgs):
    # Print images as grid    
    ax = fig.add_subplot(rows, columns, i + 1)

    img = Image.open(io.BytesIO(img_doc["image"]))
    cls = img_doc["detected_item"]
    tm = img_doc["timestamp"]
    ax.set_title(f"{cls}, date: {tm.replace(second=0, microsecond=0)}")
    ax.imshow(img)
    
plt.tight_layout()
plt.show()

client.close()
